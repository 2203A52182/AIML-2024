# %%
import pandas as pd
file=pd.read_excel("/content/charannn.xlsx")
file
# Out:
#    sno    name gender nationality  Unnamed: 4 organization  Unnamed: 6  \
# 0    1   rahul   male       india         NaN       google         NaN
# 1    2  pandit   male       china         NaN    microsoft         NaN
# 2    3   raghu   male    zimbambe         NaN       amazon         NaN
# 3    4  chintu   male       korea         NaN        wipro         NaN
#
#    work experience(in years)
# 0                         20
# 1                          3
# 2                         10
# 3                          7

# %%
import pandas as pd
file=pd.read_table("/content/charannn.txt")
file
# Out:
#    sno    name gender nationality  Unnamed: 4 organization  Unnamed: 6  \
# 0    1   rahul   male       india         NaN       google         NaN
# 1    2  pandit   male       china         NaN    microsoft         NaN
# 2    3   raghu   male    zimbambe         NaN       amazon         NaN
# 3    4  chintu   male       korea         NaN        wipro         NaN
#
#    work experience(in years)
# 0                         20
# 1                          3
# 2                         10
# 3                          7

# %%
import pandas as pd
file=pd.read_csv("/content/charannn.csv")
file
# Out:
#    sno    name gender nationality  Unnamed: 4 organization  Unnamed: 6  \
# 0    1   rahul   male       india         NaN       google         NaN
# 1    2  pandit   male       china         NaN    microsoft         NaN
# 2    3   raghu   male    zimbambe         NaN       amazon         NaN
# 3    4  chintu   male       korea         NaN        wipro         NaN
#
#    work experience(in years)
# 0                         20
# 1                          3
# 2                         10
# 3                          7
